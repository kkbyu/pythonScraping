# %%
# !brew --version
# Out:
# Homebrew 1.3.2
# Homebrew/homebrew-core (git revision aee7; last commit 2017-09-16)

# %%
# !brew install wget

# %%
# !wget http://gihyo.jp
# Out:
# --2017-09-17 16:23:28--  http://gihyo.jp/
# Resolving gihyo.jp... 104.20.33.31, 104.20.34.31, 2400:cb00:2048:1::6814:211f, ...
# Connecting to gihyo.jp|104.20.33.31|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘index.html.1’
#
# index.html.1            [ <=>                ]  70.51K  --.-KB/s    in 0.007s
#
# 2017-09-17 16:23:29 (10.2 MB/s) - ‘index.html.1’ saved [72206]

# %%
# !cat index.html
# Out:
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml" xmlns:og="http://opengraphprotocol.org/schema/" xmlns:fb="http://www.facebook.com/2008/fbml" xml:lang="ja" lang="ja">
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />
# <title>トップページ｜gihyo.jp … 技術評論社</title>
# <meta name="description" content="技術評論社提供のIT関連コンテンツサイト" />
# <meta name="keywords" content="技術評論社,gihyo.jp," />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge,chrome=1" />
# <meta name="viewport" content="width=device-width, initial-scale=1.0" />
# <meta http-equiv="Content-Script-Type" content="text/javascript" />
# <meta http-equiv="Content-Style-Type" content="text/css" />
# <meta name="twitter:card" content="summary_large_image"/>
# <meta name="twitter:site" content="@gihyojp"/>
# <meta property="og:title" content="トップページ" />
# <meta property="og:type" content="website" />
# <meta property="og:description" content="技術評論社提供のIT関連コンテンツサイト" />
# ...

# %%
# http://sample.scraping-book.com/dp
# !wget -r --no-parent -w 1 -l 1 --restrict-file-names=nocontrol http://sample.scraping-book.com/dp
# Out:
# --2017-09-17 16:23:29--  http://sample.scraping-book.com/dp
# Resolving sample.scraping-book.com... 219.94.162.21
# Connecting to sample.scraping-book.com|219.94.162.21|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 40912 (40K) [text/html]
# Saving to: ‘sample.scraping-book.com/dp’
#
# sample.scraping-boo 100%[===================>]  39.95K  --.-KB/s    in 0.06s
#
# 2017-09-17 16:23:29 (651 KB/s) - ‘sample.scraping-book.com/dp’ saved [40912/40912]
#
# Loading robots.txt; please ignore errors.
# --2017-09-17 16:23:30--  http://sample.scraping-book.com/robots.txt
# Reusing existing connection to sample.scraping-book.com:80.
# HTTP request sent, awaiting response... 200 OK
# Length: 240 [text/plain]
# Saving to: ‘sample.scraping-book.com/robots.txt’
#
# sample.scraping-boo 100%[===================>]     240  --.-KB/s    in 0s
#
# 2017-09-17 16:23:30 (25.4 MB/s) - ‘sample.scraping-book.com/robots.txt’ saved [240/240]
#
# ...

# %%
# !ls
# Out:
# ch1.ipynb                index.html               sample.scraping-book.com
# ch2.ipynb                index.html.1

# %%
# !brew install tree
# Out:
# Updating Homebrew...
# ...

# %%
# !tree sample.scraping-book.com/
# Out:
# sample.scraping-book.com/
# ├── assets
# │   └── images
# │       └── dummy.png
# ├── dp
# ├── index.html
# └── robots.txt
#
# 2 directories, 4 files

# %%
# !open sample.scraping-book.com/dp
